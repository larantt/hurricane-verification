# %%
import track_error as te

# %%
b = te.generate_cyclone("/Users/laratobias-tarsh/Documents/clim323-final/tcdata_python/format_converters/test")
# Out:
# /Users/laratobias-tarsh/opt/anaconda3/envs/tcVerification/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/laratobias-tarsh/opt/anaconda3/envs/tcVerification/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
b.ecmwf.runs
# Out:
# [Track(forecasts=[Forecast(time=Timestamp('2006-10-01 00:00:00'), lat=31.0, lon=-60.3, mslp=1016, vmax=25, track_error=120.877563992927, intensity_error=29), Forecast(time=Timestamp('2006-10-01 06:00:00'), lat=31.7, lon=-61.2, mslp=1015, vmax=31, track_error=154.28480070938556, intensity_error=30), Forecast(time=Timestamp('2006-10-01 12:00:00'), lat=32.5, lon=-61.8, mslp=1016, vmax=33, track_error=200.98340888372246, intensity_error=30), Forecast(time=Timestamp('2006-10-01 18:00:00'), lat=33.9, lon=-62.0, mslp=1016, vmax=34, track_error=212.4444886059007, intensity_error=29), Forecast(time=Timestamp('2006-10-02 00:00:00'), lat=36.2, lon=-62.3, mslp=1016, vmax=36, track_error=265.141197403198, intensity_error=28)], mean_terror=190.74629191902676, mean_ierror=29.2),
# ...

# %%
b.track_map()
